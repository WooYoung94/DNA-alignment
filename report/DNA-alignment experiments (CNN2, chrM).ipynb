# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('../log/cnn2/loss1.txt', 'r') as fs:
    
    cnn1 = eval(fs.read())

# %%
with open('../log/cnn2/loss2.txt', 'r') as fs:
    
    cnn2 = eval(fs.read())

# %%
with open('../log/cnn2/loss3.txt', 'r') as fs:
    
    cnn3 = eval(fs.read())

# %%
with open('../log/cnn2/loss4.txt', 'r') as fs:
    
    cnn4 = eval(fs.read())

# %%
fig, ax = plt.subplots(1, 1, figsize = (17, 9))

ax.plot(cnn1, label = 'cnn1') # 기본 cnn 모델에 1% augmented (저번 최종 결과)
ax.plot(cnn2, label = 'cnn2') # 기본 cnn 모델에 15% augmented
ax.plot(cnn3, label = 'cnn3') # yoonkim cnn 모델에 1% augmented
ax.plot(cnn4, label = 'cnn4') # yoonkim cnn 모델에 15% augmented
plt.axhline(y = 0.0, c = 'k', linewidth = 0.5)
ax.plot()
plt.legend()
plt.savefig('./fig.png')
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize = (17, 9))

ax.plot(cnn1[1500:], label = 'cnn1')
ax.plot(cnn2[1500:], label = 'cnn2')
ax.plot(cnn3[1500:], label = 'cnn3')
ax.plot(cnn4[1500:], label = 'cnn4')
plt.axhline(y = 0.0, c = 'k', linewidth=0.5)
ax.plot()
plt.legend()
plt.savefig('./fig.png')
plt.show()

# %%
with open('../log/cnn2/pred1.txt', 'r') as fs:
    
    cnn1_pred = eval(fs.read())

# %%
with open('../log/cnn2/pred1_per.txt', 'r') as fs:
    
    cnn1_pred_per = eval(fs.read())

# %%
with open('../log/cnn2/pred2.txt', 'r') as fs:
    
    cnn2_pred = eval(fs.read())

# %%
with open('../log/cnn2/pred2_per.txt', 'r') as fs:
    
    cnn2_pred_per = eval(fs.read())

# %%
with open('../log/cnn2/pred3.txt', 'r') as fs:
    
    cnn3_pred = eval(fs.read())

# %%
with open('../log/cnn2/pred3_per.txt', 'r') as fs:
    
    cnn3_pred_per = eval(fs.read())

# %%
with open('../log/cnn2/pred4.txt', 'r') as fs:
    
    cnn4_pred = eval(fs.read())

# %%
with open('../log/cnn2/pred4_per.txt', 'r') as fs:
    
    cnn4_pred_per = eval(fs.read())

# %%
fig, ax = plt.subplots(1, 1, figsize = (17, 17))

ax.plot(cnn1_pred, alpha = 0.8)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize = (17, 17))

ax.plot(cnn1_pred_per, alpha = 0.8)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize = (17, 17))

ax.plot(cnn2_pred, alpha = 0.8)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize = (17, 17))

ax.plot(cnn2_pred_per, alpha = 0.8)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize = (17, 17))

ax.plot(cnn3_pred, alpha = 0.8)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize = (17, 17))

ax.plot(cnn3_pred_per, alpha = 0.8)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize = (17, 17))

ax.plot(cnn4_pred, alpha = 0.8)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize = (17, 17))

ax.plot(cnn4_pred_per, alpha = 0.8)
plt.show()

# %%
with open('../log/cnn2/delta1.txt', 'r') as fs:
    
    cnn1_delta = eval(fs.read())

np.sqrt(sum(list(map(lambda x: x**2, cnn1_delta))) / len(cnn1_delta))
# Out:
# 47.839176962704414

# %%
with open('../log/cnn2/delta1_per.txt', 'r') as fs:
    
    cnn1_delta_per = eval(fs.read())

np.sqrt(sum(list(map(lambda x: x**2, cnn1_delta_per))) / len(cnn1_delta_per))
# Out:
# 722.1525628865489

# %%
with open('../log/cnn2/delta2.txt', 'r') as fs:
    
    cnn2_delta = eval(fs.read())

np.sqrt(sum(list(map(lambda x: x**2, cnn2_delta))) / len(cnn2_delta))
# Out:
# 75.87233333945798

# %%
with open('../log/cnn2/delta2_per.txt', 'r') as fs:
    
    cnn2_delta_per = eval(fs.read())

np.sqrt(sum(list(map(lambda x: x**2, cnn2_delta_per))) / len(cnn2_delta_per))
# Out:
# 722.4112022720376

# %%
with open('../log/cnn2/delta3.txt', 'r') as fs:
    
    cnn3_delta = eval(fs.read())

np.sqrt(sum(list(map(lambda x: x**2, cnn3_delta))) / len(cnn3_delta))
# Out:
# 42.7469506203328

# %%
with open('../log/cnn2/delta3_per.txt', 'r') as fs:
    
    cnn3_delta_per = eval(fs.read())

np.sqrt(sum(list(map(lambda x: x**2, cnn3_delta_per))) / len(cnn3_delta_per))
# Out:
# 334.70401054415396

# %%
with open('../log/cnn2/delta4.txt', 'r') as fs:
    
    cnn4_delta = eval(fs.read())

np.sqrt(sum(list(map(lambda x: x**2, cnn4_delta))) / len(cnn4_delta))
# Out:
# 103.76012551736618

# %%
with open('../log/cnn2/delta4_per.txt', 'r') as fs:
    
    cnn4_delta_per = eval(fs.read())

np.sqrt(sum(list(map(lambda x: x**2, cnn4_delta_per))) / len(cnn4_delta_per))
# Out:
# 435.6709778133213
